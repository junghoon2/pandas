# %%
import pandas as pd

# %%
df = pd.read_csv('01.house_price_2021.csv')

# %%
df
# Out:
#                    시군구   번지 주택유형   도로조건  연면적(㎡)  대지면적(㎡)    계약년월  계약일  \
# 0      경기도 가평군 가평읍 개곡리  7**   단독   8m미만  180.40    438.0  202101   15
# 1      경기도 가평군 가평읍 개곡리  7**   단독   8m미만  180.40    438.0  202102   19
# 2      경기도 가평군 가평읍 개곡리  1**   단독   8m미만   50.42    648.0  202104   27
# 3      경기도 가평군 가평읍 개곡리  1**   단독   8m미만   50.42    648.0  202102   27
# 4      경기도 가평군 가평읍 금대리  3**   단독  12m미만  229.02    315.0  202105    3
# ...                ...  ...  ...    ...     ...      ...     ...  ...
# 10116  경기도 화성시 향남읍 행정리   6*   단독   8m미만  115.95    403.0  202103   20
# 10117      경기도 화성시 황계동  1**   단독   8m미만   29.42    278.0  202105   20
# 10118      경기도 화성시 황계동  1**   단독   8m미만   36.36    341.0  202103    9
# 10119      경기도 화성시 황계동  1**   단독   8m미만   99.94    513.0  202104   12
# 10120      경기도 화성시 황계동  1**   단독   8m미만   77.46    555.0  202104   22
#
#       거래금액(만원)    건축년도        도로명     해제사유발생일
# 0       22,000  1997.0      당목가일길         NaN
# 1       22,000  1997.0      당목가일길         NaN
# 2        8,820  1900.0      당목가일길         NaN
# 3        8,815  1900.0      당목가일길  20210427.0
# 4      106,000  2019.0      북한강변로         NaN
# ...        ...     ...        ...         ...
# 10116   39,000  2017.0    행정죽전로2길         NaN
# 10117   27,000  2001.0       황계안길         NaN
# 10118   15,000  1970.0  황계남길123번길         NaN
# 10119   40,000  1999.0  황계남길123번길         NaN
# 10120   41,500  1947.0        황계길         NaN
#
# [10121 rows x 12 columns]

# %%
df = df.rename(columns={'거래금액(만원)': '거래금액'})

# %%
df.거래금액 = df.거래금액.str.replace(',', '').astype('int64')

# %%
city = '용인|성남|하남|남양주|광주'

# %%
df=df[df.시군구.str.contains(city)]

# %%
df
# Out:
#                시군구   번지 주택유형   도로조건  연면적(㎡)  대지면적(㎡)    계약년월  계약일    거래금액  \
# 742    경기도 광주시 경안동  1**  다가구   8m미만  184.20    109.0  202105   11   35500
# 743    경기도 광주시 경안동  1**  다가구   8m미만  165.49    187.0  202104    1   46000
# 744    경기도 광주시 경안동  1**  다가구  12m미만  388.56    263.0  202103   19  130000
# 745    경기도 광주시 경안동  1**  다가구   8m미만  569.22    384.0  202106   10  135000
# 746    경기도 광주시 경안동  1**   단독   8m미만  147.84     92.0  202105    9   29500
# ...            ...  ...  ...    ...     ...      ...     ...  ...     ...
# 9512  경기도 하남시 하산곡동  2**   단독   8m미만  275.86    195.0  202106   26  105000
# 9513  경기도 하남시 하산곡동  1**   단독   8m미만  253.84    317.0  202106    1  203000
# 9514  경기도 하남시 하산곡동  1**   단독   8m미만  198.70    356.0  202101   16   74000
# 9515  경기도 하남시 하산곡동  2**   단독   8m미만  943.64    728.0  202103   29  320000
# 9516  경기도 하남시 하산곡동   산*   단독   8m미만   86.58   4501.0  202105    2  220000
#
#         건축년도        도로명  해제사유발생일
# 742   1996.0   과수원길27번길      NaN
# 743   2007.0    경안로88번길      NaN
# 744   2003.0   포돌이로11번길      NaN
# 745   2010.0        경안로      NaN
# 746   1989.0       과수원길      NaN
# ...      ...        ...      ...
# 9512  2017.0   산곡동로86번길      NaN
# 9513  2007.0   검단산로34번길      NaN
# 9514  1990.0        검단로      NaN
# 9515  2013.0   산곡동로86번길      NaN
# 9516  1979.0  검단산로124번길      NaN
#
# [2461 rows x 12 columns]

# %%
df = df [(df.거래금액 > 50000) & (df.거래금액 < 100000) & (df.건축년도 > 1999) & (df.주택유형 == '단독')]

# %%
df
# Out:
#                      시군구   번지 주택유형   도로조건  연면적(㎡)  대지면적(㎡)    계약년월  계약일  \
# 774    경기도 광주시 곤지암읍 곤지암리  4**   단독      -   84.36    191.0  202103   15
# 823      경기도 광주시 남종면 귀여리  5**   단독  12m미만  195.10   1049.0  202106   15
# 835   경기도 광주시 남한산성면 상번천리  2**   단독   8m미만  127.60    688.0  202104   27
# 840    경기도 광주시 남한산성면 엄미리  6**   단독   8m미만  199.76    330.0  202104   10
# 860      경기도 광주시 도척면 방도리  3**   단독  12m미만  350.26    810.0  202106    9
# ...                  ...  ...  ...    ...     ...      ...     ...  ...
# 7468        경기도 용인처인구 호동   1*   단독   8m미만  219.00    426.0  202102   24
# 9419         경기도 하남시 덕풍동  4**   단독   8m미만  133.58    118.0  202105   28
# 9431         경기도 하남시 덕풍동  4**   단독  12m미만  251.50    123.0  202107    8
# 9478         경기도 하남시 신장동   9*   단독  12m미만  107.39     96.0  202103   13
# 9494         경기도 하남시 신장동  4**   단독   8m미만  221.77    127.0  202103    4
#
#        거래금액    건축년도        도로명  해제사유발생일
# 774   54000  2021.0   대석동길61번길      NaN
# 823   68000  2008.0        산수로      NaN
# 835   54500  2012.0        내곡길      NaN
# 840   51000  2009.0        엄미길      NaN
# 860   57500  2002.0        방도길      NaN
# ...     ...     ...        ...      ...
# 7468  65300  2000.0   동부로192번길      NaN
# 9419  53550  2021.0  덕풍공원로93번길      NaN
# 9431  91500  2014.0    역말로36번길      NaN
# 9478  51000  2001.0       더우개로      NaN
# 9494  58300  2018.0   신장1로28번길      NaN
#
# [427 rows x 12 columns]

# %%
df_count = df.시군구.value_counts()
#df.시군구.nunique()

# %%
df_count.to_csv('12.house_count_2021.csv', encoding='utf-8-sig')

# %%
df.to_csv('2021house_price.csv', encoding='utf-8-sig')
# utf-8-sig 해야 한글 깨지지 않는다.
