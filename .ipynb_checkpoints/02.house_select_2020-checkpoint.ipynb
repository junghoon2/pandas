# %%
import pandas as pd

# %%
df = pd.read_csv('23.house_2021.csv')

# %%
df
# Out:
#                   시군구   번지 주택유형   도로조건  연면적(㎡)   대지면적    계약년월  계약일     거래금액  \
# 0     경기도 가평군 가평읍 개곡리  7**   단독   8m미만  180.40  438.0  202101   15   22,000
# 1     경기도 가평군 가평읍 개곡리  7**   단독   8m미만  180.40  438.0  202102   19   22,000
# 2     경기도 가평군 가평읍 개곡리  1**   단독   8m미만   50.42  648.0  202102   27    8,815
# 3     경기도 가평군 가평읍 개곡리  1**   단독   8m미만   50.42  648.0  202104   27    8,820
# 4     경기도 가평군 가평읍 금대리  3**   단독  12m미만  229.02  315.0  202105    3  106,000
# ...               ...  ...  ...    ...     ...    ...     ...  ...      ...
# 9965  경기도 화성시 향남읍 행정리   6*   단독   8m미만  115.95  403.0  202103   20   39,000
# 9966      경기도 화성시 황계동  1**   단독   8m미만   29.42  278.0  202105   20   27,000
# 9967      경기도 화성시 황계동  1**   단독   8m미만   36.36  341.0  202103    9   15,000
# 9968      경기도 화성시 황계동  1**   단독   8m미만   99.94  513.0  202104   12   40,000
# 9969      경기도 화성시 황계동  1**   단독   8m미만   77.46  555.0  202104   22   41,500
#
#         건축년도        도로명     해제사유발생일
# 0     1997.0      당목가일길         NaN
# 1     1997.0      당목가일길         NaN
# 2     1900.0      당목가일길  20210427.0
# 3     1900.0      당목가일길         NaN
# 4     2019.0      북한강변로         NaN
# ...      ...        ...         ...
# 9965  2017.0    행정죽전로2길         NaN
# 9966  2001.0       황계안길         NaN
# 9967  1970.0  황계남길123번길         NaN
# 9968  1999.0  황계남길123번길         NaN
# 9969  1947.0        황계길         NaN
#
# [9970 rows x 12 columns]

# %%
df.거래금액 = df.거래금액.str.replace(',', '').astype('int64')

# %%
city = '용인|성남|하남|남양주|광주'

# %%
df=df[df.시군구.str.contains(city)]

# %%
df
# Out:
#                시군구   번지 주택유형   도로조건  연면적(㎡)    대지면적    계약년월  계약일    거래금액  \
# 732    경기도 광주시 경안동  1**  다가구   8m미만  184.20   109.0  202105   11   35500
# 733    경기도 광주시 경안동  1**  다가구   8m미만  165.49   187.0  202104    1   46000
# 734    경기도 광주시 경안동  1**  다가구  12m미만  388.56   263.0  202103   19  130000
# 735    경기도 광주시 경안동  1**  다가구   8m미만  569.22   384.0  202106   10  135000
# 736    경기도 광주시 경안동  1**   단독   8m미만  147.84    92.0  202105    9   29500
# ...            ...  ...  ...    ...     ...     ...     ...  ...     ...
# 9366  경기도 하남시 하산곡동  2**   단독   8m미만  275.86   195.0  202106   26  105000
# 9367  경기도 하남시 하산곡동  1**   단독   8m미만  253.84   317.0  202106    1  203000
# 9368  경기도 하남시 하산곡동  1**   단독   8m미만  198.70   356.0  202101   16   74000
# 9369  경기도 하남시 하산곡동  2**   단독   8m미만  943.64   728.0  202103   29  320000
# 9370  경기도 하남시 하산곡동   산*   단독   8m미만   86.58  4501.0  202105    2  220000
#
#         건축년도        도로명  해제사유발생일
# 732   1996.0   과수원길27번길      NaN
# 733   2007.0    경안로88번길      NaN
# 734   2003.0   포돌이로11번길      NaN
# 735   2010.0        경안로      NaN
# 736   1989.0       과수원길      NaN
# ...      ...        ...      ...
# 9366  2017.0   산곡동로86번길      NaN
# 9367  2007.0   검단산로34번길      NaN
# 9368  1990.0        검단로      NaN
# 9369  2013.0   산곡동로86번길      NaN
# 9370  1979.0  검단산로124번길      NaN
#
# [2424 rows x 12 columns]

# %%
df = df [(df.거래금액 > 50000) & (df.거래금액 < 100000) & (df.건축년도 > 1999) & (df.주택유형 == '단독')]

# %%
df
# Out:
#                      시군구   번지 주택유형   도로조건  연면적(㎡)    대지면적    계약년월  계약일   거래금액  \
# 764    경기도 광주시 곤지암읍 곤지암리  4**   단독      -   84.36   191.0  202103   15  54000
# 811      경기도 광주시 남종면 귀여리  5**   단독  12m미만  195.10  1049.0  202106   15  68000
# 823   경기도 광주시 남한산성면 상번천리  2**   단독   8m미만  127.60   688.0  202104   27  54500
# 828    경기도 광주시 남한산성면 엄미리  6**   단독   8m미만  199.76   330.0  202104   10  51000
# 847      경기도 광주시 도척면 방도리  3**   단독  12m미만  350.26   810.0  202106    9  57500
# ...                  ...  ...  ...    ...     ...     ...     ...  ...    ...
# 7360        경기도 용인처인구 호동   1*   단독   8m미만  219.00   426.0  202102   24  65300
# 9274         경기도 하남시 덕풍동  4**   단독   8m미만  133.58   118.0  202105   28  53550
# 9286         경기도 하남시 덕풍동  4**   단독  12m미만  251.50   123.0  202107    8  91500
# 9332         경기도 하남시 신장동   9*   단독  12m미만  107.39    96.0  202103   13  51000
# 9348         경기도 하남시 신장동  4**   단독   8m미만  221.77   127.0  202103    4  58300
#
#         건축년도        도로명  해제사유발생일
# 764   2021.0   대석동길61번길      NaN
# 811   2008.0        산수로      NaN
# 823   2012.0        내곡길      NaN
# 828   2009.0        엄미길      NaN
# 847   2002.0        방도길      NaN
# ...      ...        ...      ...
# 7360  2000.0   동부로192번길      NaN
# 9274  2021.0  덕풍공원로93번길      NaN
# 9286  2014.0    역말로36번길      NaN
# 9332  2001.0       더우개로      NaN
# 9348  2018.0   신장1로28번길      NaN
#
# [418 rows x 12 columns]

# %%
df_count = df.시군구.value_counts()
#df.시군구.nunique()

# %%
df.to_csv('2021house_price.csv', encoding='utf-8-sig')
# utf-8-sig 해야 한글 깨지지 않는다.

# %%
df_count.to_csv('12.house_count_2021.csv', encoding='utf-8-sig')
